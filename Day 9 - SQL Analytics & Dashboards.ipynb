# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql.functions import lit

# %%
# %fs
ls /Volumes/workspace/ecommerce/ecommerce_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv</td><td>2019-Nov.csv</td><td>9006762395</td><td>1767962633000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv</td><td>2019-Oct.csv</td><td>5668612855</td><td>1767962553000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/</td><td>delta/</td><td>0</td><td>1768641313682</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/incremental/</td><td>incremental/</td><td>0</td><td>1768641313682</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/parquet/</td><td>parquet/</td><td>0</td><td>1768641313682</td></tr></tbody></table></div>

# %%
df_oct = spark.read.parquet("/Volumes/workspace/ecommerce/ecommerce_data/parquet/oct/")
df_oct.limit(5).show()
# Out:
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |         event_time|event_type|product_id|        category_id|       category_code|   brand|  price|  user_id|        user_session|
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |2019-10-13 06:25:46|      view|   1002544|2053013555631882655|electronics.smart...|   apple| 460.51|518958788|e7e27c5c-1e78-481...|
# |2019-10-13 06:25:46|      view|   3700301|2053013565983425517|appliances.enviro...|   vitek| 120.93|557977070|7afc206c-7259-4be...|
# |2019-10-13 06:25:46|      view|  49100004|2127425375913902544|                NULL|    NULL|  45.05|514456508|9d6837a5-40df-49d...|
# |2019-10-13 06:25:46|      view|   9200409|2053013552913973497|computers.periphe...|defender|  12.56|512530774|df2d048d-c1ae-41b...|
# |2019-10-13 06:25:46|      view|   1306558|2053013558920217191|  computers.notebook|    acer|1801.82|523366823|0c7f0449-74d5-4b0...|
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+

# %%
# %sql
WITH daily AS (
  SELECT
    DATE(event_time) AS event_date,
    SUM(price) AS rev
  FROM ecommerce.silver.events
  WHERE event_type = 'purchase'
  GROUP BY DATE(event_time)
)
SELECT
  event_date,
  rev,
  AVG(rev) OVER (
    ORDER BY event_date
    ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
  ) AS ma7
FROM daily
ORDER BY event_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_date</th><th>rev</th><th>ma7</th></tr></thead><tbody><tr><td>2019-10-01</td><td>6275579.060000005</td><td>6275579.060000005</td></tr><tr><td>2019-10-02</td><td>6213628.530000009</td><td>6244603.795000007</td></tr><tr><td>2019-10-03</td><td>6233782.980000013</td><td>6240996.856666676</td></tr><tr><td>2019-10-04</td><td>8623058.190000024</td><td>6836512.1900000125</td></tr><tr><td>2019-10-05</td><td>7341094.460000007</td><td>6937428.6440000115</td></tr><tr><td>2019-10-06</td><td>6736895.74000001</td><td>6904006.493333344</td></tr><tr><td>2019-10-07</td><td>6347448.09</td><td>6824498.150000011</td></tr><tr><td>2019-10-08</td><td>6819701.260000012</td><td>6902229.892857155</td></tr><tr><td>2019-10-09</td><td>6855193.409999998</td><td>6993882.018571437</td></tr><tr><td>2019-10-10</td><td>6665413.209999978</td><td>7055543.480000004</td></tr><tr><td>2019-10-11</td><td>7716208.549999982</td><td>6925993.53142857</td></tr><tr><td>2019-10-12</td><td>7307691.569999985</td><td>6921221.689999996</td></tr><tr><td>2019-10-13</td><td>8457606.490000008</td><td>7167037.511428567</td></tr><tr><td>2019-10-14</td><td>9356605.16000001</td><td>7596917.092857139</td></tr><tr><td>2019-10-15</td><td>8652872.260000002</td><td>7858798.664285709</td></tr><tr><td>2019-10-16</td><td>9747164.719999984</td><td>8271937.4228571355</td></tr><tr><td>2019-10-17</td><td>9026019.069999995</td><td>8609166.831428567</td></tr><tr><td>2019-10-18</td><td>8154781.52999999</td><td>8671820.11428571</td></tr><tr><td>2019-10-19</td><td>7562479.359999994</td><td>8708218.369999997</td></tr><tr><td>2019-10-20</td><td>7515168.650000005</td><td>8573584.39285714</td></tr><tr><td>2019-10-21</td><td>7862143.639999986</td><td>8360089.889999993</td></tr><tr><td>2019-10-22</td><td>7913671.44000001</td><td>8254489.772857138</td></tr><tr><td>2019-10-23</td><td>7614084.789999997</td><td>7949764.068571426</td></tr><tr><td>2019-10-24</td><td>7470344.599999996</td><td>7727524.858571425</td></tr><tr><td>2019-10-25</td><td>7235218.340000003</td><td>7596158.688571426</td></tr><tr><td>2019-10-26</td><td>6917602.840000003</td><td>7504033.471428571</td></tr><tr><td>2019-10-27</td><td>7197520.640000003</td><td>7458655.184285713</td></tr><tr><td>2019-10-28</td><td>6591445.119999984</td><td>7277126.824285714</td></tr><tr><td>2019-10-29</td><td>6431878.879999985</td><td>7065442.172857138</td></tr><tr><td>2019-10-30</td><td>6633882.14999999</td><td>6925413.22428571</td></tr><tr><td>2019-10-31</td><td>6455216.579999994</td><td>6780394.93571428</td></tr></tbody></table></div>

# %%
# %sql
SELECT
  category_code,
  SUM(CASE WHEN event_type = 'view' THEN 1 ELSE 0 END) AS views,
  SUM(CASE WHEN event_type = 'purchase' THEN 1 ELSE 0 END) AS purchases,
  ROUND(
    SUM(CASE WHEN event_type = 'purchase' THEN 1 ELSE 0 END) * 100.0 /
    NULLIF(SUM(CASE WHEN event_type = 'view' THEN 1 ELSE 0 END), 0),
    2
  ) AS conversion_rate
FROM ecommerce.silver.events
GROUP BY category_code
ORDER BY conversion_rate DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category_code</th><th>views</th><th>purchases</th><th>conversion_rate</th></tr></thead><tbody><tr><td>electronics.smartphone</td><td>10617170</td><td>337978</td><td>3.18</td></tr><tr><td>kids.fmcg.diapers</td><td>24201</td><td>768</td><td>3.17</td></tr><tr><td>electronics.audio.headphone</td><td>1018303</td><td>30501</td><td>3.00</td></tr><tr><td>appliances.iron</td><td>157611</td><td>3652</td><td>2.32</td></tr><tr><td>appliances.kitchen.microwave</td><td>164925</td><td>3708</td><td>2.25</td></tr><tr><td>medicine.tools.tonometer</td><td>13970</td><td>310</td><td>2.22</td></tr><tr><td>appliances.personal.scales</td><td>62603</td><td>1331</td><td>2.13</td></tr><tr><td>electronics.video.tv</td><td>1055799</td><td>21561</td><td>2.04</td></tr><tr><td>appliances.environment.water_heater</td><td>138762</td><td>2774</td><td>2.00</td></tr><tr><td>appliances.ironing_board</td><td>34263</td><td>664</td><td>1.94</td></tr><tr><td>appliances.kitchen.washer</td><td>831107</td><td>16146</td><td>1.94</td></tr><tr><td>electronics.tablet</td><td>301939</td><td>5602</td><td>1.86</td></tr><tr><td>stationery.cartrige</td><td>7379</td><td>134</td><td>1.82</td></tr><tr><td>appliances.kitchen.toster</td><td>25939</td><td>459</td><td>1.77</td></tr><tr><td>computers.peripherals.printer</td><td>145591</td><td>2496</td><td>1.71</td></tr><tr><td>appliances.kitchen.kettle</td><td>178543</td><td>2983</td><td>1.67</td></tr><tr><td>computers.components.hdd</td><td>62651</td><td>1035</td><td>1.65</td></tr><tr><td>appliances.personal.hair_cutter</td><td>63751</td><td>1047</td><td>1.64</td></tr><tr><td>appliances.environment.air_heater</td><td>153379</td><td>2483</td><td>1.62</td></tr><tr><td>appliances.environment.vacuum</td><td>771939</td><td>12378</td><td>1.60</td></tr><tr><td>appliances.kitchen.blender</td><td>194404</td><td>3043</td><td>1.57</td></tr><tr><td>electronics.telephone</td><td>238526</td><td>3738</td><td>1.57</td></tr><tr><td>electronics.camera.photo</td><td>11157</td><td>174</td><td>1.56</td></tr><tr><td>appliances.kitchen.meat_grinder</td><td>155530</td><td>2382</td><td>1.53</td></tr><tr><td>electronics.audio.microphone</td><td>28393</td><td>430</td><td>1.51</td></tr><tr><td>computers.peripherals.mouse</td><td>70176</td><td>1051</td><td>1.50</td></tr><tr><td>appliances.kitchen.mixer</td><td>87664</td><td>1260</td><td>1.44</td></tr><tr><td>computers.notebook</td><td>1106205</td><td>15588</td><td>1.41</td></tr><tr><td>electronics.clocks</td><td>1272669</td><td>17902</td><td>1.41</td></tr><tr><td>null</td><td>13235496</td><td>173409</td><td>1.31</td></tr><tr><td>appliances.sewing_machine</td><td>148030</td><td>1939</td><td>1.31</td></tr><tr><td>construction.tools.saw</td><td>139403</td><td>1820</td><td>1.31</td></tr><tr><td>auto.accessories.alarm</td><td>187629</td><td>2441</td><td>1.30</td></tr><tr><td>appliances.kitchen.refrigerators</td><td>863296</td><td>11217</td><td>1.30</td></tr><tr><td>computers.components.memory</td><td>42092</td><td>526</td><td>1.25</td></tr><tr><td>appliances.environment.fan</td><td>2172</td><td>27</td><td>1.24</td></tr><tr><td>appliances.kitchen.oven</td><td>190981</td><td>2335</td><td>1.22</td></tr><tr><td>appliances.kitchen.juicer</td><td>46239</td><td>554</td><td>1.20</td></tr><tr><td>electronics.audio.music_tools.piano</td><td>35397</td><td>423</td><td>1.20</td></tr><tr><td>construction.tools.welding</td><td>91247</td><td>1081</td><td>1.18</td></tr><tr><td>construction.components.faucet</td><td>25482</td><td>297</td><td>1.17</td></tr><tr><td>auto.accessories.radar</td><td>42348</td><td>494</td><td>1.17</td></tr><tr><td>appliances.kitchen.coffee_grinder</td><td>11584</td><td>132</td><td>1.14</td></tr><tr><td>computers.peripherals.keyboard</td><td>52561</td><td>600</td><td>1.14</td></tr><tr><td>construction.tools.generator</td><td>111719</td><td>1244</td><td>1.11</td></tr><tr><td>furniture.bathroom.to ...

# %%
# %sql
WITH customer_metrics AS (
  SELECT
    user_id,
    COUNT(*) AS cnt,
    SUM(price) AS total_spent
  FROM ecommerce.silver.events
  WHERE event_type = 'purchase'
  GROUP BY user_id
)
SELECT
  CASE
    WHEN cnt >= 10 THEN 'VIP'
    WHEN cnt >= 5 THEN 'Loyal'
    ELSE 'Regular'
  END AS tier,
  COUNT(*) AS customers,
  ROUND(AVG(total_spent), 2) AS avg_ltv
FROM customer_metrics
GROUP BY tier
ORDER BY avg_ltv DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tier</th><th>customers</th><th>avg_ltv</th></tr></thead><tbody><tr><td>VIP</td><td>7781</td><td>7230.81</td></tr><tr><td>Loyal</td><td>19114</td><td>2109.34</td></tr><tr><td>Regular</td><td>320223</td><td>416.43</td></tr></tbody></table></div>
