# %% [markdown]
# # Workflow

# %%
# %fs
ls /Volumes/workspace/ecommerce/ecommerce_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv</td><td>2019-Nov.csv</td><td>9006762395</td><td>1767962633000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv</td><td>2019-Oct.csv</td><td>5668612855</td><td>1767962553000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/delta/</td><td>delta/</td><td>0</td><td>1768491754453</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/incremental/</td><td>incremental/</td><td>0</td><td>1768491754453</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/parquet/</td><td>parquet/</td><td>0</td><td>1768491754453</td></tr></tbody></table></div>

# %%
dbutils.widgets.text("input_path", "", "Input Path")
dbutils.widgets.text("run_date", "", "Run Date")

# %%
input_path = dbutils.widgets.get("input_path")
run_date = dbutils.widgets.get("run_date")

print("Input Path:", input_path)
print("Run Date:", run_date)
# Out:
# Input Path: /Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv
# Run Date:

# %%
bronze_df = spark.read.csv(input_path, header=True, inferSchema=True)

bronze_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.ecommerce.bronze_events")
