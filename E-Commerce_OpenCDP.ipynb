# %%
print(dbutils.notebook.entry_point.getDbutils().notebook().getContext().browserHostName().get())

# %%
# %fs rm -r /Workspace/Repos/venkat.mce38@gmail.com

# %%
# %sh
cd /Volumes/workspace/default/raw_data

for file in *.zip
do
  echo "Unzipping $file"
  unzip -o "$file"
  rm "$file"
done

echo "✅ All ZIP files unzipped and deleted."

# %%
dbutils.fs.ls("/Volumes/workspace/default/raw_data")

# %%
# %sh
cd /Volumes/workspace/default/raw_data
ls -lh

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.ecommerce")

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.ecommerce.ecommerce_data;

# %%
dbutils.fs.ls("/Volumes/workspace/ecommerce/ecommerce_data")

# %%
dbutils.fs.mv(
    "/Volumes/workspace/default/raw_data/2019-Oct.csv",
    "/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv"
)

dbutils.fs.mv(
    "/Volumes/workspace/default/raw_data/2019-Nov.csv",
    "/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv"
)

# %%
dbutils.fs.ls("/Volumes/workspace/ecommerce/ecommerce_data")

# %%
def load_ecommerce_data(month):
    path = f"/Volumes/workspace/ecommerce/ecommerce_data/2019-{month}.csv"
    
    df = spark.read.option("header", "true").option("inferSchema", "true") \
        .csv(path)
    
    return df

# %%
events = load_ecommerce_data("Oct")
display(events.limit(5))

# %%
# Create simple DataFrame
data_sample = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299)]
df1 = spark.createDataFrame(data_sample, ["product", "price"])
df1.show()

# Filter expensive products
df1.filter(df1.price > 1000).show()

# %%
spark.range(10).display()
