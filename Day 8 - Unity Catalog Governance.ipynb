# %%
# %sql
CREATE CATALOG IF NOT EXISTS ecommerce;

CREATE SCHEMA IF NOT EXISTS ecommerce.bronze;
CREATE SCHEMA IF NOT EXISTS ecommerce.silver;
CREATE SCHEMA IF NOT EXISTS ecommerce.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Bronze
CREATE TABLE IF NOT EXISTS ecommerce.bronze.events
AS SELECT * FROM workspace.ecommerce.bronze_events;

-- Silver
CREATE TABLE IF NOT EXISTS ecommerce.silver.events
AS SELECT * FROM workspace.ecommerce.silver_events;

-- Gold
CREATE TABLE IF NOT EXISTS ecommerce.gold.products
AS SELECT * FROM workspace.ecommerce.gold_distinct_users_per_product;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
GRANT USE CATALOG ON CATALOG ecommerce TO analysts;
GRANT USE CATALOG ON CATALOG ecommerce TO engineers;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4919266376341051>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'GRANT USE CATALOG ON CATALOG ecommerce TO analysts;\nGRANT USE CATALOG ON CATALOG ecommerce TO engineers;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
GRANT USE CATALOG ON CATALOG ecommerce TO `venkat.mce38@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA ecommerce.gold TO `venkat.mce38@gmail.com`;
GRANT SELECT ON TABLE ecommerce.gold.products TO `venkat.mce38@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
GRANT USE CATALOG ON CATALOG ecommerce TO `venkat.mce38@gmail.com`;
GRANT USE SCHEMA ON SCHEMA ecommerce.gold TO `venkat.mce38@gmail.com`;
GRANT SELECT ON TABLE ecommerce.gold.products TO `venkat.mce38@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
GRANT SELECT ON TABLE ecommerce.bronze.events TO `venkat.mce38@gmail.com`;
GRANT SELECT ON TABLE ecommerce.silver.events TO `venkat.mce38@gmail.com`;
GRANT SELECT ON TABLE ecommerce.gold.products TO `venkat.mce38@gmail.com`;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4919266376341049>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'GRANT SELECT, INSERT, UPDATE, DELETE ON TABLE ecommerce.bronze.events TO `venkat.mce38@gmail.com`;\nGRANT SELECT, INSERT, UPDATE, DELETE ON TABLE ecommerce.silver.events TO `venkat.mce38@gmail.com`;\nGRANT SELECT ON TABLE ecommerce.gold.products TO `venkat.mce38@gmail.com`;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
# ...

# %%
# %sql
CREATE OR REPLACE VIEW ecommerce.gold.v_top_products AS
SELECT
    product_id,
    distinct_users
FROM ecommerce.gold.products
WHERE distinct_users > 10
ORDER BY distinct_users DESC
LIMIT 100;

# %%
# %sql
GRANT SELECT ON VIEW ecommerce.gold.v_top_products TO `venkat.mce38@gmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE CATALOG ecommerce;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4919266376341065>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE CATALOG ecommerce;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:194, in SqlMagic.sql(self, line, cell)
#     188 except BaseException as e:
# ...
